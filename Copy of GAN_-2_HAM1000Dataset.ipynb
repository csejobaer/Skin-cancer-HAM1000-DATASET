# %%
# !mkdir -p ~/.kaggle
from google.colab import drive
from google.colab import files
# Upload your kaggle.json API key
uploaded = files.upload()

drive.mount('/content/drive')
# Out:
#      <input type="file" id="files-07df80d3-06de-4a58-9b14-f0fd785196aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07df80d3-06de-4a58-9b14-f0fd785196aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import shutil
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/Machine-learning'

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import Adam
import pandas as pd
print("Import ok!")
# Out:
# Import ok!

# %%
data = pd.read_csv('/content/drive/MyDrive/Machine-learning/hmnist_28_28_RGB.csv')

# %%
y = data['label']
x = data.drop(columns = ['label'])
len(x )
# Out:
# 10015

# %%
tabular_data = pd.read_csv('/content/drive/MyDrive/Machine-learning/HAM10000_metadata.csv')

# %%
classes = {4: ('nv', ' melanocytic nevi'), 6: ('mel', 'melanoma'), 2 :('bkl', 'benign keratosis-like lesions'), 1:('bcc' , ' basal cell carcinoma'), 5: ('vasc', ' pyogenic granulomas and hemorrhage'), 0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  3: ('df', 'dermatofibroma')}
classes
# Out:
# {4: ('nv', ' melanocytic nevi'),
#  6: ('mel', 'melanoma'),
#  2: ('bkl', 'benign keratosis-like lesions'),
#  1: ('bcc', ' basal cell carcinoma'),
#  5: ('vasc', ' pyogenic granulomas and hemorrhage'),
#  0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
#  3: ('df', 'dermatofibroma')}

# %%
import seaborn as sns

# %% [markdown]
# #Number of sample for specific disease

# %%
# Count the occurrences of each disease class
class_counts = tabular_data['dx'].value_counts()

# Retrieve x-coordinate (disease class) data as an array
disease_classes = class_counts.index.to_numpy()

# Retrieve y-coordinate (frequency) data as an array
frequencies = class_counts.values

print("Disease Classes:", disease_classes)
print("Frequencies:", frequencies)
# Out:
# Disease Classes: ['nv' 'mel' 'bkl' 'bcc' 'akiec' 'vasc' 'df']
# Frequencies: [6705 1113 1099  514  327  142  115]

# %%
# Calculate the percentages of each gender category
gender_percentages = tabular_data['sex'].value_counts(normalize=True) * 100

# Retrieve x-coordinate (gender categories) data as an array
gender_categories = gender_percentages.index.to_numpy()

# Retrieve y-coordinate (percentages) data as an array
percentages = gender_percentages.values

print("Gender Categories:", gender_categories)
print("Percentages:", percentages)
# Out:
# Gender Categories: ['male' 'female' 'unknown']
# Percentages: [53.97903145 45.45182227  0.56914628]

# %%
# Calculate the histogram of age values
age_histogram = tabular_data['age'].value_counts()

# Retrieve x-coordinate (age values) data as an array
age_values = age_histogram.index.to_numpy()

# Retrieve y-coordinate (counts) data as an array
counts = age_histogram.values

print("Age Values:", age_values)
print("Counts:", counts)
# Out:
# Age Values: [45. 50. 55. 40. 60. 70. 35. 65. 75. 30. 80. 85. 25. 20.  5. 15. 10.  0.]
# Counts: [1299 1187 1009  985  803  756  753  731  618  464  404  290  247  169
#    86   77   41   39]

# %%
# Count the occurrences of each combination of localization and sex
value = tabular_data[['localization', 'sex']].value_counts().to_frame()
value.reset_index(level=[1, 0], inplace=True)
temp = value.rename(columns={'localization': 'location', 0: 'count'})

# Retrieve x-coordinate (location and sex categories) data as arrays
locations_sex = temp['location'].to_numpy()
sex_categories = temp['sex'].to_numpy()

# Retrieve y-coordinate (counts) data as an array
counts = temp['count'].to_numpy()

print("Location and Sex Categories:", locations_sex)
print("Sex Categories:", sex_categories)
print("Counts:", counts)
# Out:
# Location and Sex Categories: ['back' 'lower extremity' 'lower extremity' 'back' 'trunk' 'trunk'
#  'upper extremity' 'abdomen' 'upper extremity' 'abdomen' 'face' 'face'
#  'chest' 'foot' 'foot' 'chest' 'scalp' 'neck' 'unknown' 'unknown' 'neck'
#  'hand' 'unknown' 'genital' 'hand' 'scalp' 'ear' 'ear' 'genital' 'acral'
#  'trunk' 'foot' 'back' 'abdomen']
# Sex Categories: ['male' 'female' 'male' 'female' 'male' 'female' 'male' 'male' 'female'
#  'female' 'male' 'female' 'male' 'female' 'male' 'female' 'male' 'male'
#  'female' 'male' 'female' 'female' 'unknown' 'female' 'male' 'female'
#  'female' 'male' 'male' 'female' 'unknown' 'unknown' 'unknown' 'unknown']
# Counts: [1347 1152  925  843  763  638  622  587  496  433  397  348  265  173
#   143  142   97   95   95   92   73   57   47   34   33   31   30   26
#    14    7    3    3    2    2]

# %% [markdown]
# #Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)

# %%
x = np.array(x).reshape(-1,28,28,3)
print('Shape of X :',x.shape)
# Out:
# Shape of X : (46935, 28, 28, 3)

# %% [markdown]
# #Standardization and Splitting Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_standardized = (x - np.mean(x)) / np.std(x)
# Reshape the standardized 'x' if it has more than two dimensions
num_samples = x_standardized.shape[0]
x_flattened = x_standardized.reshape(num_samples, -1)

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(x_flattened, y, test_size=0.2, random_state=1)

# %%
# Standardize features (optional but recommended)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Generator network

# %%
# Load the HAM10000 dataset and preprocess (replace with your actual data loading code)
# ...

# Define constants
latent_dim = 100
epochs = 20000
batch_size = 128

# Build and compile the discriminator
discriminator = Sequential()
discriminator.add(Flatten(input_shape=(28, 28, 3)))  # Adjust input shape for HAM10000
discriminator.add(Dense(512))
discriminator.add(LeakyReLU(alpha=0.2))
discriminator.add(Dense(256))
discriminator.add(LeakyReLU(alpha=0.2))
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])

# Build the generator
generator = Sequential()
generator.add(Dense(256, input_dim=latent_dim))
generator.add(LeakyReLU(alpha=0.2))
generator.add(BatchNormalization(momentum=0.8))
generator.add(Dense(512))
generator.add(LeakyReLU(alpha=0.2))
generator.add(BatchNormalization(momentum=0.8))
generator.add(Dense(28*28*3, activation='tanh'))  # Adjust output shape for HAM10000
generator.add(Reshape((28, 28, 3)))  # Adjust reshape for HAM10000

# Build and compile the GAN model
discriminator.trainable = False
gan = Sequential([generator, discriminator])
gan.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))

# Training loop
for epoch in range(epochs):
    # Train discriminator
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    real_imgs = X_train[idx]
    fake_imgs = generator.predict(np.random.randn(batch_size, latent_dim))
    d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size, 1)))
    d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size, 1)))
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train generator
    noise = np.random.randn(batch_size, latent_dim)
    g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))

    # Print progress and save generated images
    if epoch % 100 == 0:
        print(f"Epoch {epoch}, D Loss: {d_loss[0]}, G Loss: {g_loss}")
        generated_imgs = generator.predict(np.random.randn(16, latent_dim))
        plt.figure(figsize=(4, 4))
        for i in range(generated_imgs.shape[0]):
            plt.subplot(4, 4, i + 1)
            plt.imshow(generated_imgs[i])
            plt.axis("off")
        plt.tight_layout()
        plt.show()
# Out:
# 4/4 [==============================] - 4s 4ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-bf5148d5cf23> in <cell line: 36>()
#      39     real_imgs = X_train[idx]
#      40     fake_imgs = generator.predict(np.random.randn(batch_size, latent_dim))
# ---> 41     d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size, 1)))
#      42     d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size, 1)))
#      43     d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2508             )
#    2509             self.train_function = self.make_train_function()
# -> 2510             logs = self.train_function(iterator)
#    2511
# ...

# %% [markdown]
# # Discriminator network
